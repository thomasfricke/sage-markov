# %% [markdown]
# # Diffusion simulated

# %% [markdown]
# ## Compile cython code

# %%
dir=os.getcwd()

os.chdir("..")
load('./diffusion/markovian.spyx')
os.chdir(dir)

# %% [markdown]
# # Dimension = 1

# %%
m1=Markovian.demo(dimension=1,peak=100000,seed=0L, decay_rate=0, size=500)

# %%
m1.non_empty_cells()
# Out:
# {250: 100000}

# %%
m1.reactivity()
# Out:
# 100000.0

# %%
m1.run(10)
# Out:
# 0.0

# %%
m1.run_until(10.0)

# %%
upper=int(m1.size/2+4.0*m1.time())
lower=int(m1.size/2-4.0*m1.time())
m1.plot(lower,upper)+m1.analytic_plot(lower,upper)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
m1.plot(lower,upper)+list_plot(m1.gauss(),color='green')+m1.analytic_plot(lower,upper)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
pl=m1.analytic()

# %%
pl(m1.size/2)
# Out:
# 12615.657984408706

# %%
print( m1.sum_walker() )
# Out:
# 100000

# %%
m1.dimension
# Out:
# 1

# %%
m1.destroy()
# Out:
# 0

# %% [markdown]
# # Dimension = 2

# %%
m2=Markovian.demo(dimension=2)

# %%
m2.run_until(100)
# Out:
# 6376686

# %%
m2.plot(5000,5100)+m2.analytic_plot(5000,5100)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
heatmap=[ [ m2.cell(i) for i in range(m2.size*r+20,m2.size*(r+1)-20)  ] for r in range(20,m2.size-20) ]

# %%
from sage.plot.matrix_plot import MatrixPlot

# %%
import matplotlib.cm; 
matplotlib.cm.datad.keys()
# Out:
# dict_keys(['Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c'])

# %%
matrix_plot(heatmap, cmap='gnuplot',colorbar=true)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
coords(5050)
# Out:
# [50, 50]

# %%
m2.destroy()
# Out:
# 0

# %% [markdown]
# # Dimension=3

# %%
m3=Markovian.demo(dimension=3)

# %%
m3.run_until(40)
# Out:
# 3327421

# %%
m3.plot(505030,505070)+m3.analytic_plot(505030,505070)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
m3.destroy()
# Out:
# 0

# %%
cells
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6654134b3dad> in <module>
# ----> 1 cells
#
# NameError: name 'cells' is not defined

# %%
# %%python3
#
# import cv2
# import numpy as np
# img = np.random.randint(222, size=(500, 500,3))
# gen = np.array(img ,dtype=np.uint8)
# cv2.imshow('i',gen)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import numpy as np
np.random.randint?
# Out:
# Docstring:
#    randint(low, high=None, size=None, dtype=int)
#
#    Return random integers from low (inclusive) to high (exclusive).
#
#    Return random integers from the "discrete uniform" distribution of
#    the specified dtype in the "half-open" interval [low, high). If
#    high is None (the default), then results are from [0, low).
#
#    Note:
#
#      New code should use the "integers" method of a "default_rng()"
#      instance instead; see random-quick-start.
#
#    low : int or array-like of ints
#       Lowest (signed) integers to be drawn from the distribution
#       (unless "high=None", in which case this parameter is one above
#       the *highest* such integer).
#
#    high : int or array-like of ints, optional
#       If provided, one above the largest (signed) integer to be drawn
#       from the distribution (see above for behavior if "high=None").
#       If array-like, must contain integer values
#
#    size : int or tuple of ints, optional
# ...
