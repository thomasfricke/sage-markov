# %%
load('markovian.spyx')
# Out:
# Compiling ./markovian.spyx...

# %%
m1=Markovian.demo(dimension=1,peak=1000000,decay_rate=0.001)

# %%
m1.run(10000000)
# Out:
# 11.050834354476505

# %%
m1.plot(30,70)+m1.analytic_plot(30,70)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
pl=m1.analytic()

# %%
pl(50)
# Out:
# 8925.685176632132

# %%
m1.dimension
# Out:
# 1

# %%
m2=Markovian.demo(dimension=2)

# %%
m2.run(1000000)
# Out:
# 22.06244010661308

# %%
m2.plot(5000,5100)+m2.analytic_plot(5000,5100)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
m3=Markovian.demo(dimension=3)

# %%
m3.run(1000000)
# Out:
# 22.02510846696662

# %%
m3.plot(505030,505070)+m3.analytic_plot(505030,505070)
# Out:
# Graphics object consisting of 2 graphics primitives
